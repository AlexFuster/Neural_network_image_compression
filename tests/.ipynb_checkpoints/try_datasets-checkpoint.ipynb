# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
from scipy.stats import describe
import tensorflow as tf
import sys
from sklearn.utils import resample
sys.path.append('../src')
from training import training_CAE
from encoder import encoder_CAE
from decoder import decoder_CAE
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import math
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset=np.load('../data/full_archive.npz')['image']
dataset=[img for img in dataset if img.shape==(512,512)]
dataset=np.array(dataset)
dataset.shape
# Out:
# (467, 512, 512)

# %%
plt.matshow(dataset[0])
plt.show()

# %%
describe(dataset[0],axis=None)
# Out:
# DescribeResult(nobs=262144, minmax=(-1024.0, 3071.0), mean=-539.4666175842285, variance=231742.92158047497, skewness=0.6116190937553415, kurtosis=-0.27756401354819316)
