# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import tensorflow as tf
import sys
from sklearn.utils import resample
sys.path.append('../src')
from training import training_CAE
from encoder import encoder_CAE
from decoder import decoder_CAE
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.decomposition import PCA
import math
import os
from utils import get_next_log_name, show_images
# Out:
# /home/alex/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
dataset=np.load('../data/full_archive.npz')['image']
dataset=[img for img in dataset if img.shape==(512,512)]
dataset=np.array(dataset)-dataset.min()
dataset=(4095*dataset/dataset.max()).round()
dataset.shape
# Out:
# (467, 512, 512)

# %%
show_images([dataset[0],dataset[1]])

# %%
dataset+=2000

# %%
dataset=dataset.round()

# %%
dataset.min(),dataset.max()
# Out:
# (0.0, 4095.0)

# %%
show_images([dataset[0],dataset[1]])

# %%
get_next_log_name('log_dir_medical/')
# Out:
# 'log_dir_medical/1'

# %%
_,last_entropy=training_CAE(log_dir).train(X['train'],None,50000,2)
